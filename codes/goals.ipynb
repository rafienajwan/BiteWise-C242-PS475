# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import json
import os

# %%
# Load data
user_data_path = "C:/Users/NABIL/Documents/Tugas Matkul/Bangkit/Capstone_2/BiteWise-C242-PS475/result/user_data.json"
food_data_path = "C:/Users/NABIL/Documents/Tugas Matkul/Bangkit/Capstone_2/BiteWise-C242-PS475/codes/food_data.json"
tracker_memory_path = "C:/Users/NABIL/Documents/Tugas Matkul/Bangkit/Capstone_2/BiteWise-C242-PS475/result/tracker_memory.json"

with open(user_data_path, "r") as f:
    user_data = json.load(f)

with open(food_data_path, "r") as f:
    food_data = json.load(f)

with open(tracker_memory_path, "r") as f:
    tracker_memory = json.load(f)

# %%
import json
import random

# Path ke file user_data.json
user_data_path = "C:/Users/NABIL/Documents/Tugas Matkul/Bangkit/Capstone_2/BiteWise-C242-PS475/result/user_data.json"

# Baca file JSON
with open(user_data_path, 'r') as f:
    user_data = json.load(f)

# Menambahkan kolom 'goal_weight' untuk setiap user dengan nilai random
for user in user_data:
    # Ambil nilai weight dan konversi ke angka (hapus " kg")
    weight = float(user['weight'].replace(' kg', ''))
    
    # Randomisasi goal_weight antara weight-5 dan weight+20
    user['goal_weight'] = random.randint(int(weight - 5), int(weight + 20))

# Simpan kembali data yang telah diperbarui ke dalam file JSON
with open(user_data_path, 'w') as f:
    json.dump(user_data, f, indent=4)

print("Kolom 'goal_weight' berhasil ditambahkan dengan nilai random.")
# Out:
# Kolom 'goal_weight' berhasil ditambahkan dengan nilai random.

# %%
user_data = pd.DataFrame(user_data)

# Preprocessing function
def preprocess_data(user):
    # Pastikan 'tall' dan 'weight' bertipe string sebelum manipulasi
    user['tall'] = user['tall'].astype(str).str.replace(" cm", "").astype(float)
    user['weight'] = user['weight'].astype(str).str.replace(" kg", "").astype(float)
    
    # Mapping level aktivitas ke nilai numerik
    user['ActiveLevel'] = user['ActiveLevel'].map({
        "sedentary": 1.2,
        "lightly active": 1.375,
        "moderately active": 1.55,
        "very active": 1.725
    })
    
    return user

# Terapkan preprocessing
user_data = preprocess_data(user_data)

# Menampilkan hasil untuk verifikasi
print(user_data[['user_name', 'tall', 'weight', 'ActiveLevel']])
# Out:
#     user_name   tall  weight  ActiveLevel
# 0       User1  169.0    75.0        1.200
# 1       User2  174.0    50.0        1.200
# 2       User3  168.0    97.0        1.725
# 3       User4  160.0    51.0        1.375
# 4       User5  179.0    71.0          NaN
# ..        ...    ...     ...          ...
# 995   User996  159.0    84.0        1.375
# 996   User997  153.0    57.0        1.200
# 997   User998  158.0    77.0        1.375
# 998   User999  171.0    78.0          NaN
# 999  User1000  156.0    69.0        1.200
#
# [1000 rows x 4 columns]

# %%
import pandas as pd

# Pastikan user_data adalah DataFrame dan telah berisi data yang benar
user_data = pd.DataFrame(user_data)

# Pastikan kolom bertipe numerik dan melakukan konversi jika diperlukan
user_data['tall'] = user_data['tall'].astype(float)
user_data['weight'] = user_data['weight'].astype(float)
user_data['age'] = user_data['age'].astype(int)

# Fungsi untuk menghitung BMR
def calculate_bmr(user):
    if user['gender'] == 'male':
        return 10 * user['weight'] + 6.25 * user['tall'] - 5 * user['age'] + 5
    else:
        return 10 * user['weight'] + 6.25 * user['tall'] - 5 * user['age'] - 161

# Menambahkan kolom BMR dan TDEE
user_data['BMR'] = user_data.apply(calculate_bmr, axis=1)

# Untuk menghitung TDEE, Anda perlu mengonversi ActiveLevel terlebih dahulu ke dalam angka
activity_multiplier = {
    "sedentary": 1.2,
    "lightly active": 1.375,
    "moderately active": 1.55,
    "very active": 1.725
}

user_data['ActiveLevel'] = user_data['ActiveLevel'].map(activity_multiplier)

# Menghitung TDEE
user_data['TDEE'] = user_data['BMR'] * user_data['ActiveLevel']

# Output untuk memastikan kolom ditambahkan dengan benar
print(user_data[['user_name', 'BMR', 'TDEE']])
# Out:
#     user_name      BMR  TDEE
# 0       User1  1661.25   NaN
# 1       User2  1186.50   NaN
# 2       User3  1574.00   NaN
# 3       User4  1335.00   NaN
# 4       User5  1572.75   NaN
# ..        ...      ...   ...
# 995   User996  1553.75   NaN
# 996   User997  1276.25   NaN
# 997   User998  1517.50   NaN
# 998   User999  1497.75   NaN
# 999  User1000  1470.00   NaN
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

# Pastikan user_data adalah DataFrame
user_data = pd.DataFrame(user_data)

# Pastikan kolom bertipe numerik
user_data['tall'] = user_data['tall'].astype(float)
user_data['weight'] = user_data['weight'].astype(float)
user_data['age'] = user_data['age'].astype(int)
user_data['goal_weight'] = user_data['goal_weight'].astype(float)

# Fungsi untuk menghitung BMR
def calculate_bmr(user):
    if user['gender'] == 'male':
        return 10 * user['weight'] + 6.25 * user['tall'] - 5 * user['age'] + 5
    else:
        return 10 * user['weight'] + 6.25 * user['tall'] - 5 * user['age'] - 161

# Tambahkan kolom BMR dan TDEE
user_data['BMR'] = user_data.apply(calculate_bmr, axis=1)
user_data['TDEE'] = user_data['BMR'] * user_data['ActiveLevel']

# Output untuk memastikan kolom ditambahkan dengan benar
print(user_data[['user_name', 'BMR', 'TDEE']])
# Out:
#     user_name      BMR  TDEE
# 0       User1  1661.25   NaN
# 1       User2  1186.50   NaN
# 2       User3  1574.00   NaN
# 3       User4  1335.00   NaN
# 4       User5  1572.75   NaN
# ..        ...      ...   ...
# 995   User996  1553.75   NaN
# 996   User997  1276.25   NaN
# 997   User998  1517.50   NaN
# 998   User999  1497.75   NaN
# 999  User1000  1470.00   NaN
#
# [1000 rows x 3 columns]

# %%
# Target: Days to reach goal weight
def calculate_days_to_goal(user):
    weight_difference = abs(user['weight'] - user['goal_weight'])
    calorie_deficit = 7700  # Approximate calories per kg of body weight
    daily_deficit = 500  # Example deficit for weight loss
    return (weight_difference * calorie_deficit) / daily_deficit

user_data['goal_days'] = user_data.apply(calculate_days_to_goal, axis=1)
print(user_data[['goal_days']])
# Out:
#      goal_days
# 0        231.0
# 1        308.0
# 2        200.2
# 3        277.2
# 4         30.8
# ..         ...
# 995      123.2
# 996       77.0
# 997       46.2
# 998      231.0
# 999       92.4
#
# [1000 rows x 1 columns]

# %%
X = user_data[['tall', 'weight', 'age', 'ActiveLevel', 'BMR', 'TDEE']]  # Fitur input
y = user_data['goal_weight']  # Target: goal weight

# %%
# Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# C:\Users\NABIL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1137: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\NABIL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1142: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\NABIL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1162: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
# Split data menjadi train dan test (80% train, 20% test)
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.3),  # Dropout untuk menghindari overfitting
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  # Output layer untuk prediksi goal weight
])

# Kompilasi model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)  # Optimizer Adam dengan learning rate lebih rendah
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# %%
# Pelatihan model
history = model.fit(X_train, y_train, epochs=5000, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2550.7444 - mae: 46.6943 - val_loss: 2708.8857 - val_mae: 47.9154
# Epoch 2/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2548.4570 - mae: 46.6700 - val_loss: 2706.5571 - val_mae: 47.8910
# Epoch 3/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2546.1799 - mae: 46.6456 - val_loss: 2704.2217 - val_mae: 47.8667
# Epoch 4/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2543.9075 - mae: 46.6211 - val_loss: 2701.8726 - val_mae: 47.8421
# Epoch 5/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2541.6282 - mae: 46.5966 - val_loss: 2699.5303 - val_mae: 47.8176
# Epoch 6/5000
# 25/25 [==============================] - 0s 2ms/step - loss: 2539.3508 - mae: 46.5722 - val_loss: 2697.1938 - val_mae: 47.7932
# Epoch 7/5000
# ...

# %%
# Evaluasi model pada data test
test_loss, test_mae = model.evaluate(X_val, y_val)  # Menggunakan X_val dan y_val sebagai data test
print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 414.5294 - mae: 17.3993
# Test Loss: 414.5294
# Test MAE: 17.3993

# %%
# Contoh data baru untuk prediksi (input baru)
new_user = np.array([[170, 80, 25, 1.375, 1800, 2500]])  # Data baru (tall, weight, age, ActiveLevel, BMR, TDEE)

# Standarisasi data baru menggunakan scaler yang sama
new_user_scaled = scaler.transform(new_user)

# Membuat prediksi menggunakan model
predicted_goal_weight = model.predict(new_user_scaled)

print(f"Predicted Goal Weight: {predicted_goal_weight[0][0]:.2f} kg")
# Out:
# 1/1 [==============================] - 0s 74ms/step
# Predicted Goal Weight: 75.93 kg
# C:\Users\NABIL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Membuat prediksi untuk seluruh data validasi (X_val)
y_pred = model.predict(X_val)

# Menampilkan beberapa contoh prediksi vs nilai sebenarnya
comparison_df = pd.DataFrame({
    'Actual Goal Weight': y_val,
    'Predicted Goal Weight': y_pred.flatten()  # Mengubah hasil prediksi menjadi 1D array
})

print(comparison_df.head())
# Out:
# 7/7 [==============================] - 0s 920us/step
#      Actual Goal Weight  Predicted Goal Weight
# 521               107.0              75.925102
# 737                96.0              75.925102
# 740                64.0              75.925102
# 660                61.0              75.925102
# 411                39.0              75.925102
